# %%
str=input("string:")
newline=""
for x in str:
    if x=='c':
        newline+='r'
    else:
        newline+=x
print(newline)

# %% [markdown]
# Algorithm
# ------------------
#
# // input a string
#
# // outputs the string with replaced character
# read string
#
# newline=""
#
# for x in string:
#
# if x == 'c':
#
# replaces the c
#
# else normally assign character-
#
# to the newline.
#
# prints string with change

# %%
string=input("string:=")
newline=""
for i in range(len(string)):
    if string[i]=='c':
        newline+='r'
    else:
        newline+=string[i]
print(newline)
